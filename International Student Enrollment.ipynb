# %%
# import all libraries

import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import plotly.io as pio
import plotly.express as px
import plotly.figure_factory as ff
from datetime import datetime
from datetime import timedelta

# %%
# read in csv file from Github repo

data = pd.read_csv('https://raw.githubusercontent.com/Tinashe-04/NewInternationalStudentsEnrollment/main/International%20Student%20and%20US%20Higher%20Education%20Enrollment%20-%20Enrollment%201949-2022%20CSV.csv')
data
# Out:
#    International Student and U.S. Higher Education Enrollment, 1948/49 - 2022/23  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                Year
# 3                                             1948/49
# 4                                             1949/50
# ..                                                ...
# 83  *  Projection of Total U.S. Higher Education. ...
# 84  ** Refugees were counted from 1975/76 to 1990/91.
# 85  *** OPT was first reported separately for the ...
# 86                                                NaN
# 87  Suggested citation: Institute of International...
#
#                  Unnamed: 1                         Unnamed: 2  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2   Enrolled Int'l Students  Optional Practical Training (OPT)
# ...

# %%
# check how to use set_option method to display all rows of a dataframe
pd.set_option?
# Out:
# Signature:   pd.set_option(*args, **kwds) -> 'T'
# Type:        CallableDynamicDoc
# String form: <pandas._config.config.CallableDynamicDoc object at 0x10e731370>
# File:        ~/anaconda3/envs/xeus-python/lib/python3.12/site-packages/pandas/_config/config.py
# Docstring:
# set_option(pat, value)
#
# Sets the value of the specified option.
#
# Available options:
#
# - compute.[use_bottleneck, use_numba, use_numexpr]
# - display.[chop_threshold, colheader_justify, date_dayfirst, date_yearfirst,
#   encoding, expand_frame_repr, float_format]
# - display.html.[border, table_schema, use_mathjax]
# - display.[large_repr, max_categories, max_columns, max_colwidth, max_dir_items,
#   max_info_columns, max_info_rows, max_rows, max_seq_items, memory_usage,
#   min_rows, multi_sparse, notebook_repr_html, pprint_nest_depth, precision,
#   show_dimensions]
# - display.unicode.[ambiguous_as_wide, east_asian_width]
# - display.[width]
# - io.excel.ods.[reader, writer]
# - io.excel.xls.[reader]
# ...

# %%
# use max_info_rows to display all rows
pd.set_option('display.max_info_rows', 100)

# %%
data
# Out:
#    International Student and U.S. Higher Education Enrollment, 1948/49 - 2022/23  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                Year
# 3                                             1948/49
# 4                                             1949/50
# ..                                                ...
# 83  *  Projection of Total U.S. Higher Education. ...
# 84  ** Refugees were counted from 1975/76 to 1990/91.
# 85  *** OPT was first reported separately for the ...
# 86                                                NaN
# 87  Suggested citation: Institute of International...
#
#                  Unnamed: 1                         Unnamed: 2  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2   Enrolled Int'l Students  Optional Practical Training (OPT)
# ...

# %%
# corrected method to max_rows
pd.set_option('display.max_rows', 100)

# %%
data
# Out:
#    International Student and U.S. Higher Education Enrollment, 1948/49 - 2022/23  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                Year
# 3                                             1948/49
# 4                                             1949/50
# 5                                             1950/51
# 6                                             1951/52
# 7                                             1952/53
# 8                                             1953/54
# 9                                             1954/55
# 10                                            1955/56
# 11                                            1956/57
# 12                                            1957/58
# 13                                            1958/59
# 14                                            1959/60
# 15                                            1960/61
# ...

# %%
# apply max_columns to view all of the columns
pd.set_option('display.max_columns', 100)
data
# Out:
#    International Student and U.S. Higher Education Enrollment, 1948/49 - 2022/23  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                Year
# 3                                             1948/49
# 4                                             1949/50
# 5                                             1950/51
# 6                                             1951/52
# 7                                             1952/53
# 8                                             1953/54
# 9                                             1954/55
# 10                                            1955/56
# 11                                            1956/57
# 12                                            1957/58
# 13                                            1958/59
# 14                                            1959/60
# 15                                            1960/61
# ...

# %%
# obtain a list of all of the methods and attribute I can call with read_csv() function
dir(pd.read_csv)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']

# %%
# read documentation of read_csv() function to look for arguments
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
# ...

# %%
# use skiprows parameter to skip the starting rows at the start of the dataset and read into a new dataframe 

more_data = pd.read_csv('https://raw.githubusercontent.com/Tinashe-04/NewInternationalStudentsEnrollment/main/International%20Student%20and%20US%20Higher%20Education%20Enrollment%20-%20Enrollment%201949-2022%20CSV.csv', skiprows=3)
more_data
# Out:
#                                                  Year Enrolled Int'l Students  \
# 0                                             1948/49                       -
# 1                                             1949/50                       -
# 2                                             1950/51                       -
# 3                                             1951/52                       -
# 4                                             1952/53                       -
# 5                                             1953/54                       -
# 6                                             1954/55                       -
# 7                                             1955/56                       -
# 8                                             1956/57                       -
# 9                                             1957/58                       -
# 10                                            1958/59                       -
# ...

# %%
# list comprehension will create a list and is therefore less efficient, so use the regular for loop notation
# display the notes seen at the bottom of the csv before dropping the rows
for i in range(76,85):
    print(more_data.loc[i]['Year'])
# Out:
# *  Data from the National Center for Education Statistics (NCES).
# **  The data collection process was changed in 1974/75.
# Refugees were counted from 1975/76 to 1990/91.
# *** OPT was first reported separately for the 1979/80 academic year.
# *  Projection of Total U.S. Higher Education. Source: National Center for Education Statistics
# ** Refugees were counted from 1975/76 to 1990/91.
# *** OPT was first reported separately for the 1979/80 academic year.
# nan
# Suggested citation: Institute of International Education. (2023). "International Student and U.S. Higher Education Enrollment, 1948/49 - 2023/23" Open Doors Report on International Educational Exchange. Retrieved from https://opendoorsdata.org/.

# %%
# drop the extra rows
more_data.drop(list(range(76,85)), inplace=True, axis=0)
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0      1948/49                       -                                 -
# 1      1949/50                       -                                 -
# 2      1950/51                       -                                 -
# 3      1951/52                       -                                 -
# 4      1952/53                       -                                 -
# 5      1953/54                       -                                 -
# 6      1954/55                       -                                 -
# 7      1955/56                       -                                 -
# 8      1956/57                       -                                 -
# 9      1957/58                       -                                 -
# 10     1958/59                       -                                 -
# 11     1959/60                       -                                 -
# ...

# %%
# one more row to drop
more_data.drop(75, axis=0, inplace=True)
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0      1948/49                       -                                 -
# 1      1949/50                       -                                 -
# 2      1950/51                       -                                 -
# 3      1951/52                       -                                 -
# 4      1952/53                       -                                 -
# 5      1953/54                       -                                 -
# 6      1954/55                       -                                 -
# 7      1955/56                       -                                 -
# 8      1956/57                       -                                 -
# 9      1957/58                       -                                 -
# 10     1958/59                       -                                 -
# 11     1959/60                       -                                 -
# ...

# %%
# a couple more rows to drop
more_data.drop(list(range(0,30)), axis=0, inplace=True)
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 30     1978/79                       -                                 -
# 31  1979/80***                 283,503                             2,840
# 32     1980/81                 308,432                             3,450
# 33     1981/82                 323,419                             2,880
# 34     1982/83                 333,365                             3,620
# 35     1983/84                 335,494                             3,400
# 36     1984/85                 337,803                             4,310
# 37     1985/86                 339,627                             4,150
# 38     1986/87                 344,879                             4,730
# 39     1987/88                 351,387                             4,800
# 40    1988/89                  359,334                             7,020
# 41     1989/90                 379,139                             7,712
# ...

# %%
# one more row to drop, again
more_data.drop(30, axis=0, inplace=True)
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 31  1979/80***                 283,503                             2,840
# 32     1980/81                 308,432                             3,450
# 33     1981/82                 323,419                             2,880
# 34     1982/83                 333,365                             3,620
# 35     1983/84                 335,494                             3,400
# 36     1984/85                 337,803                             4,310
# 37     1985/86                 339,627                             4,150
# 38     1986/87                 344,879                             4,730
# 39     1987/88                 351,387                             4,800
# 40    1988/89                  359,334                             7,020
# 41     1989/90                 379,139                             7,712
# 42     1990/91                 398,759                             8,770
# ...

# %%
# tried to reset the index
more_data.reset_index()
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 31  1979/80***                 283,503                             2,840
# 32     1980/81                 308,432                             3,450
# 33     1981/82                 323,419                             2,880
# 34     1982/83                 333,365                             3,620
# 35     1983/84                 335,494                             3,400
# 36     1984/85                 337,803                             4,310
# 37     1985/86                 339,627                             4,150
# 38     1986/87                 344,879                             4,730
# 39     1987/88                 351,387                             4,800
# 40    1988/89                  359,334                             7,020
# 41     1989/90                 379,139                             7,712
# 42     1990/91                 398,759                             8,770
# ...

# %%
# forgot to add inplace=True argument
more_data.set_index('Year')
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 31  1979/80***                 283,503                             2,840
# 32     1980/81                 308,432                             3,450
# 33     1981/82                 323,419                             2,880
# 34     1982/83                 333,365                             3,620
# 35     1983/84                 335,494                             3,400
# 36     1984/85                 337,803                             4,310
# 37     1985/86                 339,627                             4,150
# 38     1986/87                 344,879                             4,730
# 39     1987/88                 351,387                             4,800
# 40    1988/89                  359,334                             7,020
# 41     1989/90                 379,139                             7,712
# 42     1990/91                 398,759                             8,770
# ...

# %%
# reset the index to default
more_data.reset_index()
# Out:
#     index        Year Enrolled Int'l Students  \
# 0      31  1979/80***                 283,503
# 1      32     1980/81                 308,432
# 2      33     1981/82                 323,419
# 3      34     1982/83                 333,365
# 4      35     1983/84                 335,494
# 5      36     1984/85                 337,803
# 6      37     1985/86                 339,627
# 7      38     1986/87                 344,879
# 8      39     1987/88                 351,387
# 9      40    1988/89                  359,334
# 10     41     1989/90                 379,139
# 11     42     1990/91                 398,759
# 12     43     1991/92                 411,355
# 13     44     1992/93                 427,608
# 14     45     1993/94                 438,319
# 15     46     1994/95                 439,427
# 16     47     1995/96                 438,337
# 17     48     1996/97                 439,859
# 18     49     1997/98                 464,698
# ...

# %%
# finally got a clean index
more_data.reset_index(drop=True, inplace=True)
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***                 283,503                             2,840
# 1      1980/81                 308,432                             3,450
# 2      1981/82                 323,419                             2,880
# 3      1982/83                 333,365                             3,620
# 4      1983/84                 335,494                             3,400
# 5      1984/85                 337,803                             4,310
# 6      1985/86                 339,627                             4,150
# 7      1986/87                 344,879                             4,730
# 8      1987/88                 351,387                             4,800
# 9     1988/89                  359,334                             7,020
# 10     1989/90                 379,139                             7,712
# 11     1990/91                 398,759                             8,770
# ...

# %%
# display column names
more_data.columns
# Out:
# Index(['Year', 'Enrolled Int'l Students', 'Optional Practical Training (OPT)',
#        'Total Int'l Students', 'Annual % Change', 'Total U.S. Enrollment*',
#        '% Int'l'],
#       dtype='object')

# %%
# make a plot to display how international student enrollment has evolved since 1980
fig = plt.figure(figsize=(16,16))
ax = plt.axes()

ax.plot(more_data['Year'], more_data['Enrolled Int\'l Students'], color='r', marker='o');
ax.set_xticks(['1980/81', '1990/91', '2000/01', '2010/11', '2020/21']);

# %%
# display data types
more_data.dtypes
# Out:
# Year                                 object
# Enrolled Int'l Students              object
# Optional Practical Training (OPT)    object
# Total Int'l Students                 object
# Annual % Change                      object
# Total U.S. Enrollment*               object
# % Int'l                              object
# dtype: object

# %%
# change data types for each numeric column
col_list = [more_data.columns[x] for x in [1,2,3,5]]

more_data['Enrolled Int\'l Students'] = [i.strip(',') for i in more_data['Enrolled Int\'l Students']]
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***                 283,503                             2,840
# 1      1980/81                 308,432                             3,450
# 2      1981/82                 323,419                             2,880
# 3      1982/83                 333,365                             3,620
# 4      1983/84                 335,494                             3,400
# 5      1984/85                 337,803                             4,310
# 6      1985/86                 339,627                             4,150
# 7      1986/87                 344,879                             4,730
# 8      1987/88                 351,387                             4,800
# 9     1988/89                  359,334                             7,020
# 10     1989/90                 379,139                             7,712
# 11     1990/91                 398,759                             8,770
# ...

# %%
more_data['Enrolled Int\'l Students'] = [i.split(',') for i in more_data['Enrolled Int\'l Students']]
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***              [283, 503]                             2,840
# 1      1980/81              [308, 432]                             3,450
# 2      1981/82              [323, 419]                             2,880
# 3      1982/83              [333, 365]                             3,620
# 4      1983/84              [335, 494]                             3,400
# 5      1984/85              [337, 803]                             4,310
# 6      1985/86              [339, 627]                             4,150
# 7      1986/87              [344, 879]                             4,730
# 8      1987/88              [351, 387]                             4,800
# 9     1988/89               [359, 334]                             7,020
# 10     1989/90              [379, 139]                             7,712
# 11     1990/91              [398, 759]                             8,770
# ...

# %%
more_data['Enrolled Int\'l Students'] = [i[0] + i[1] for i in more_data['Enrolled Int\'l Students']]
more_data
# Out:
#           Year Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***                  283503                             2,840
# 1      1980/81                  308432                             3,450
# 2      1981/82                  323419                             2,880
# 3      1982/83                  333365                             3,620
# 4      1983/84                  335494                             3,400
# 5      1984/85                  337803                             4,310
# 6      1985/86                  339627                             4,150
# 7      1986/87                  344879                             4,730
# 8      1987/88                  351387                             4,800
# 9     1988/89                   359334                             7,020
# 10     1989/90                  379139                             7,712
# 11     1990/91                  398759                             8,770
# ...

# %%
more_data['Enrolled Int\'l Students'] = [int(i) for i in more_data['Enrolled Int\'l Students']]
more_data
# Out:
#           Year  Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                             2,840
# 1      1980/81                   308432                             3,450
# 2      1981/82                   323419                             2,880
# 3      1982/83                   333365                             3,620
# 4      1983/84                   335494                             3,400
# 5      1984/85                   337803                             4,310
# 6      1985/86                   339627                             4,150
# 7      1986/87                   344879                             4,730
# 8      1987/88                   351387                             4,800
# 9     1988/89                    359334                             7,020
# 10     1989/90                   379139                             7,712
# 11     1990/91                   398759                             8,770
# ...

# %%
more_data.dtypes
# Out:
# Year                                 object
# Enrolled Int'l Students               int64
# Optional Practical Training (OPT)    object
# Total Int'l Students                 object
# Annual % Change                      object
# Total U.S. Enrollment*               object
# % Int'l                              object
# dtype: object

# %%
more_data['Optional Practical Training (OPT)'] = [i.split(',') for i in more_data['Optional Practical Training (OPT)']]
more_data
# Out:
#           Year  Enrolled Int'l Students Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                          [2, 840]
# 1      1980/81                   308432                          [3, 450]
# 2      1981/82                   323419                          [2, 880]
# 3      1982/83                   333365                          [3, 620]
# 4      1983/84                   335494                          [3, 400]
# 5      1984/85                   337803                          [4, 310]
# 6      1985/86                   339627                          [4, 150]
# 7      1986/87                   344879                          [4, 730]
# 8      1987/88                   351387                          [4, 800]
# 9     1988/89                    359334                          [7, 020]
# 10     1989/90                   379139                          [7, 712]
# 11     1990/91                   398759                          [8, 770]
# ...

# %%
more_data['Optional Practical Training (OPT)'] = [i[0] + i[1] for i in more_data['Optional Practical Training (OPT)']]
more_data['Optional Practical Training (OPT)'] = [int(i) for i in more_data['Optional Practical Training (OPT)']]
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
more_data.dtypes
# Out:
# Year                                 object
# Enrolled Int'l Students               int64
# Optional Practical Training (OPT)     int64
# Total Int'l Students                 object
# Annual % Change                      object
# Total U.S. Enrollment*               object
# % Int'l                              object
# dtype: object

# %%
def convert_to_int(string):
    '''
    Purpose: formatting the strings to remove commas and change data type to int data type
    Inputs: string to be formatted
    Returns: final_number, an int which is the result of the proper formatting
    '''
    final_number = 0

    # split the string up into components on either side of the comma
    first_list = string.split(',')

    # add all of the components together to produce one string
    number = ''.join(first_list)

    # convert that last string to an int
    final_number = int(number)

    return final_number

more_data['Total Int\'l Students'] = more_data['Total Int\'l Students'].apply(convert_to_int)
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
more_data['Total U.S. Enrollment*'] = more_data['Total U.S. Enrollment*'].apply(convert_to_int)
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
more_data.dtypes
# Out:
# Year                                 object
# Enrolled Int'l Students               int64
# Optional Practical Training (OPT)     int64
# Total Int'l Students                  int64
# Annual % Change                      object
# Total U.S. Enrollment*                int64
# % Int'l                              object
# dtype: object

# %%
more_data['Annual % Change'] = [float(x) for x in more_data['Annual % Change']]
more_data['% Int\'l'] = [float(y) for y in more_data['% Int\'l']]
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
more_data.dtypes
# Out:
# Year                                  object
# Enrolled Int'l Students                int64
# Optional Practical Training (OPT)      int64
# Total Int'l Students                   int64
# Annual % Change                      float64
# Total U.S. Enrollment*                 int64
# % Int'l                              float64
# dtype: object

# %%
# make a plot to display how international student enrollment has evolved since 1980
fig = plt.figure(figsize=(10,10))
ax = plt.axes()

ax.plot(more_data['Year'], more_data['Enrolled Int\'l Students'], color='r', marker='o');
ax.set_xticks(['1980/81', '1990/91', '2000/01', '2010/11', '2020/21']);

# %%
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
# make a plot to display how international student enrollment has evolved since 1980
fig = plt.figure()
ax = plt.axes()

ax.plot(more_data['Year'], more_data['Optional Practical Training (OPT)'], color='b', marker='o');
ax.set_xticks(['1980/81', '1990/91', '2000/01', '2010/11', '2020/21']);
ax.set_xlabel('Selected Years');
ax.set_ylabel('Number of Students');

# %%
### plotting the OPT numbers as an interactive line graph

# import the plotly library for graphing objects
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(x=more_data['Year'], y=more_data['Optional Practical Training (OPT)'])])
fig.layout.title = f'OPT Students by each academic {'year'}'
fig.show()

# %%
fig = px.line(data_frame=more_data,
              x='Year', 
              y='Optional Practical Training (OPT)',
              title='Optional Practical Training students from 1980-2023',
              hover_name='Optional Practical Training (OPT)')

fig.show()

# %%
fig = px.line(data_frame=more_data,
              x='Year', 
              y=['Enrolled Int\'l Students', 'Total Int\'l Students', 'Optional Practical Training (OPT)'],
              title='Optional Practical Training students from 1980-2023',
              hover_name='Optional Practical Training (OPT)')

fig.show()

# %%
more_data['% OPT'] = round(more_data['Optional Practical Training (OPT)'] / more_data['Total Int\'l Students'], 4) * 100
more_data
# Out:
#           Year  Enrolled Int'l Students  Optional Practical Training (OPT)  \
# 0   1979/80***                   283503                               2840
# 1      1980/81                   308432                               3450
# 2      1981/82                   323419                               2880
# 3      1982/83                   333365                               3620
# 4      1983/84                   335494                               3400
# 5      1984/85                   337803                               4310
# 6      1985/86                   339627                               4150
# 7      1986/87                   344879                               4730
# 8      1987/88                   351387                               4800
# 9     1988/89                    359334                               7020
# 10     1989/90                   379139                               7712
# ...

# %%
fig = px.line(data_frame=more_data,
              x='Year', 
              y='% OPT',
              title='Percentage of International Students on OPT ')
fig.show()
